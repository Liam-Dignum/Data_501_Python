# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[118], line 9
#       7 from sklearn import metrics
#       8 from sklearn.metrics import roc_curve, auc
# ----> 9 import accuracy_score
#
# ModuleNotFoundError: No module named 'accuracy_score'

# %%
titanicdf =sns.load_dataset('titanic')
titanicdf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
filteredDF = titanicdf.drop_duplicates()
filteredDF = filteredDF.drop(columns = ['embark_town','deck','age','embarked','who','class'])

# %%
filteredDF.isna().sum()

#filteredDF['embarked'] = filteredDF['embarked'].fillna(filteredDF['embarked'].mode())
filteredDF
# Out:
#      survived  pclass     sex  sibsp  parch     fare  adult_male alive  alone
# 0           0       3    male      1      0   7.2500        True    no  False
# 1           1       1  female      1      0  71.2833       False   yes  False
# 2           1       3  female      0      0   7.9250       False   yes   True
# 3           1       1  female      1      0  53.1000       False   yes  False
# 4           0       3    male      0      0   8.0500        True    no   True
# ..        ...     ...     ...    ...    ...      ...         ...   ...    ...
# 885         0       3  female      0      5  29.1250       False    no  False
# 887         1       1  female      0      0  30.0000       False   yes   True
# 888         0       3  female      1      2  23.4500       False    no  False
# 889         1       1    male      0      0  30.0000        True   yes   True
# 890         0       3    male      0      0   7.7500        True    no   True
#
# [784 rows x 9 columns]

# %%
filteredDF = filteredDF.replace(to_replace=['male','female'], value= ['1','0'])

#filteredDF['embarked'] = filteredDF['embarked'].replace(to_replace= 'nan' , value= filteredDF['embarked'].mode())
#filteredDF['embarked'].unique()
filteredDF.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# sibsp         0
# parch         0
# fare          0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %%
Y = filteredDF['alive']
X = filteredDF.drop(columns=['alive'])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.25,random_state=16)

# %%
logreg = LogisticRegression(random_state=16,max_iter=1000)

logreg.fit(X_train,Y_train)

Y_pred = logreg.predict(X_test)

# %%
cnf_matrix = metrics.confusion_matrix(Y_test,Y_pred)
cnf_matrix
# Out:
# array([[106,   0],
#        [  0,  90]])

# %%
Y_prob = logreg.predict_proba(X_test)[:,1]
Y_pred = np.where(Y_pred == 'yes', 1,0)

# %%
fpr , tpr, _ = roc_curve(Y_test,Y_prob)
#roc_curve = metrics.roc_curve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 fpr , tpr, _ = roc_curve(Y_test,Y_prob)
#       2 #roc_curve = metrics.roc_curve()
#
# File c:\Python\mini_project\liam-dignum-mini-project\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
# ...
